# %% [markdown]
# # **Radiation - Net radiation**
# Complete documentation: https://osf.io/yzbhp/
#     - Author Michele Bottazzi and Concetta D'Amato
#     - Licence Creative Commons 4.0

# %% [markdown]
# Net radiation is a balance between incoming and outgoing radiation at a point on the Earth's surface; it is often divided into short wave and long wave.
#
# $$ Rn=(1-\alpha)(Rs+d)+Rl_d-Rl_u $$
#
#  - Rn: radiazione netta [$MJ \cdot m^{2} \cdot day^{−1}$]
#  - $\alpha$: albedo
#  - Rs: radiazione ad onda corta diretta [$MJ \cdot m^{2} \cdot day^{−1}$]
#  - d: radiazione ad onda corta diffusa [$MJ \cdot m^{2} \cdot day^{−1}$]
#  - Rl_d: radiazione ad onda lunga rilasciata dall'atmosfera [$MJ \cdot m^{2} \cdot day^{−1}$]
#  - Rl_u: radiazione ad onda lunga rilascita dal suolo [$MJ \cdot m^{2} \cdot day^{−1}$]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import calendar
import gf
from IPython.display import Image

# %%
###########################
### SET THE FOLDER PATH ###
###########################
oms_project_path = os.path.dirname(os.getcwd())
os.chdir(oms_project_path)
#os.listdir()

# %%
os.chdir(oms_project_path+'/data/Cavone')
nameFile='Cavone_Net.csv'

# %%
dfNet = pd.read_csv(nameFile,
                 skiprows=6, sep=',', parse_dates=[0], 
                 na_values=-9999,usecols=[1,2])
dfNet.columns = ['Datetime','Net']
dfNet.index = dfNet['Datetime']
dfNet = dfNet.iloc[:,1:]
dfNet.head(3)
# Out:
#                      Net
# Datetime
# 2013-12-15 00:00:00  0.0
# 2013-12-15 01:00:00  0.0
# 2013-12-15 02:00:00  0.0

# %%
ax=dfNet.plot(color="#1b6ca8",figsize=(15,7))
ax.set_title('Net Radiation',size=20)
ax.set_ylabel("NR [$W \cdot m^{−2}$]",size=15)
ax.set_xlabel("Datetime",size=15)
# Out:
# Text(0.5, 0, 'Datetime')

# %% [markdown]
# ## Different plot

# %%
import plotly.graph_objects as go
import plotly.express as px
import pandas as pd
df = pd.read_csv(nameFile,skiprows=6, sep=',', parse_dates=[0], na_values=-9999,usecols=[1,2])
fig = px.line(df, x='Datetime', y='Net', title='Time Series Net Radiation')
fig.update_xaxes(rangeslider_visible=True)
fig.show()
