# %% [markdown]
# # **GEOframe-NewAGE winter school**
# # **Day 4 - Radiation lesson**

# %% [markdown]
# In this lesson we will run the radiation simulations.
# - Skyview factor
# - Shortwave radiation
# - Clearness index
# - Longwave radiation
# - Net radiation
# - Raster radiation (longwave only)

# %% [markdown]
# ## **Longwave radiation**
# Complete documentation: https://osf.io/a4pfk/

# %% [markdown]
# This component deals with the downwelling ($L_{\downarrow}$) and upwelling ($L_{\uparrow}$) longwave atmospheric radiation. Longwave radiation (1-100 μm) is an important component of the radiation balance on Earth which affects many phenomena such as evapotranspiration, snow melt, glaciers evolution , vegetation dynamics, plant respiration, and primary productivity.
# Many simplified models (SM) have been proposed in order to model $L_{\downarrow}$ and $L_{\uparrow}$ by using easily available meteorological observation such as air temperature, relative humidity, incoming solar radiation, and cloud cover. Ten SM for estimating $L_{\uparrow}$ and one for $L_{\downarrow}$ were integrated in the LWRB component.

# %% [markdown]
# ### **Component Description**
# SMs formulation for $L_{\uparrow}$ [Wm −2 ] and $L_{\downarrow}$ [Wm −2 ] are based on the Stefan-Boltzmann equation:
# \begin{equation}
# L_{\downarrow} = \epsilon_{all-sky} · \sigma · T_{a}^{4} \\
# L_{\uparrow}= \epsilon_{s} · \sigma · T_{s}^{4}
# \end{equation}
# where:
# - $\sigma = 5.670\cdot 10^{-8}$ is the Stefan-Boltzmann constant,
# - $\epsilon_{all-sky}$ [-] is the atmosphere effective emissivity,
# - $\epsilon_{s}$ [-] is the soil emissivity
# - $T_{a}$ [K] is the near-surface air temperature,
# - $T_{s}$ is the surface soil temperature.
#
# In order to account for the increase of $L_{\downarrow}$ in cloud cover conditions is formulated according to equation:
# \begin{equation}
# \epsilon_{all−sky} = \epsilon_{clear} \cdot (1 + a \cdot c^{b})
# \end{equation}
# where:
# - c [-] is the clearness index
# - a and b are two calibration coefficients.
#
# Ten literature formulations were implemented for the computation of $\epsilon_{clear}$. The complete list of parameterizations used is presented in table 1 where it is specified: the component number, the component name, the equation that defines it, and the reference to the paper from which it is derived. X, Y and Z are the parameters provided in literature for each model.

# %%
projFolder = '/home/drugo/Desktop/MeledrioCaseStudy-winterSchool/'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from IPython.display import Image

os.chdir(projFolder)
Image("Images/lwrb1.png")

# %%
Image("Images/lwrb2.png")

# %% [markdown]
# The formulation of the $L_{\uparrow}$ requires the soil emissivity, which usually is a property of the nature of surface, and the surface soil temperature. Table 3 shows the literature values of the soil emissivity for different types of surface: $\epsilon_{s}$ varies from its minimum of 0.95 for the bare soils up to its maximum of 0.99 for the fresh snow

# %%
Image("Images/lwrb3.png")

# %% [markdown]
# ### **Detailed Inputs description**
# #### **General description**
# The input file is a .csv file containing a header and one or more time series of input data, depending on the number of stations involved. Each column of the file is associated to a different station. The file must have the following header:
# - The first 3 rows with general information such as the date of the creation of the file and the author;
# - The fourth and fifth rows contain the IDs of the stations (e.g. station number 8: value 8, ID, ,8);
# - The sixth row contains the information about the type of the input data (in this case, one column with the date and one column with double values);
# - The seventh row specifies the date format (YYYY-MM-dd HH:mm).
# #### **Clearness index**
# The clearness index is the ratio between the measured incoming solar radiation (Im) and the theoretical solar radiation computed at the top atmosphere (I top). This quantity is given in <span style='color:red'>**time series**</span> or <span style='color:red'>**raster maps**</span> of adimensional values between 0 and 1.
# #### **Relative humidity**
# The relative humidity is given in <span style='color:red'>**time series**</span> or <span style='color:red'>**raster maps**</span> of (%) values. All the conversions are made by the component.
# #### **Air temperature**
# The air temperature is given in <span style='color:red'>**time series**</span> or <span style='color:red'>**raster maps**</span> of (°C) values. The conversion in Kevin degrees is directly done by the component
# #### **Soil temperature**
# The soil temperature is given in <span style='color:red'>**time series**</span> or <span style='color:red'>**raster maps**</span> of (°C) values.The conversion in (K) is directly done by the component.
# #### **Skyview factor**
# The sky view factor is a <span style='color:red'>**raster map**</span> of adimensional values in the interval [0,1] at the given point.
# #### **Model**
# The model is a String <span style='color:red'>**parameter**</span> containing the number of the model chosen according to table 2.
# #### **X, Y, Z**
# X,Y, and Z are the double values <span style='color:red'>**parameters**</span> of the model parameters chosen according to table 2

# %% [markdown]
# ### **Detailed Outputs description**
# The output file will have exactly the same heading of the input file.
# #### **$L_{\downarrow}$**
# The $L_{\downarrow}$ output is given as a time series at a given point or as raster maps. Its units are $W/m^{2}$.
# #### **$L_{\uparrow}$**
# The $L_{\uparrow}$ output is given as a time series at a given point or as raster maps. Its units are $W/m^{2}$.

# %% [markdown]
# **Run longwave simulation**

# %%
# %load simulation/Radiation/LongWave.sim

# %%
#!docker run --rm -it -v $(pwd):/work omslab/oms simulation/Radiation/LongWave.sim

# %% [markdown]
# Read the shortwave radiation results

# %%
nameLw6File = 'output/Radiation/LongwaveUpwelling2010_Model6.csv'

# %%
dfLw6= pd.read_csv(nameLw6File,sep=',',skiprows=6,low_memory=False)
dfLw6.head()
# Out:
#    Format  yyyy-MM-dd HH:mm  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0     NaN  2013-01-01 00:00  290.427110  294.637194  288.933490  291.203817
# 1     NaN  2013-01-01 01:00  290.176136  293.783624  288.527293  291.297583
# 2     NaN  2013-01-01 02:00  290.978753  293.727489  287.398894  289.588148
# 3     NaN  2013-01-01 03:00  289.840444  292.461794  286.021164  287.677529
# 4     NaN  2013-01-01 04:00  288.908426  291.635618  284.789117  289.336223
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8
# 0  291.522491  294.171333  291.982273
# 1  291.844342  294.431647  292.489398
# 2  292.824360  294.338034  291.734777
# 3  292.117132  294.722219  286.311714
# 4  291.230065  295.151594  285.419526

# %%
dfLw6.rename(columns={list(dfLw6)[1]:'Datetime'}, inplace=True)
dfLw6[dfLw6 ==-9999]=np.nan
dfLw6.head()
# Out:
#    Format          Datetime  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0     NaN  2013-01-01 00:00  290.427110  294.637194  288.933490  291.203817
# 1     NaN  2013-01-01 01:00  290.176136  293.783624  288.527293  291.297583
# 2     NaN  2013-01-01 02:00  290.978753  293.727489  287.398894  289.588148
# 3     NaN  2013-01-01 03:00  289.840444  292.461794  286.021164  287.677529
# 4     NaN  2013-01-01 04:00  288.908426  291.635618  284.789117  289.336223
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8
# 0  291.522491  294.171333  291.982273
# 1  291.844342  294.431647  292.489398
# 2  292.824360  294.338034  291.734777
# 3  292.117132  294.722219  286.311714
# 4  291.230065  295.151594  285.419526

# %%
for x in range(2, 9):
    dfLw6.rename(columns={list(dfLw6)[x]:x-1}, inplace=True)

# %%
dfLw6.head()
# Out:
#    Format          Datetime           1           2           3           4  \
# 0     NaN  2013-01-01 00:00  290.427110  294.637194  288.933490  291.203817
# 1     NaN  2013-01-01 01:00  290.176136  293.783624  288.527293  291.297583
# 2     NaN  2013-01-01 02:00  290.978753  293.727489  287.398894  289.588148
# 3     NaN  2013-01-01 03:00  289.840444  292.461794  286.021164  287.677529
# 4     NaN  2013-01-01 04:00  288.908426  291.635618  284.789117  289.336223
#
#             5           6           7
# 0  291.522491  294.171333  291.982273
# 1  291.844342  294.431647  292.489398
# 2  292.824360  294.338034  291.734777
# 3  292.117132  294.722219  286.311714
# 4  291.230065  295.151594  285.419526

# %%
dfLw6['Datetime'] = pd.to_datetime(dfLw6['Datetime'], dayfirst=True)
dfLw6['Datetime'] = dfLw6['Datetime'].dt.strftime('%Y-%m-%d %H:%M')
dfLw6.index = dfLw6.Datetime

# %%
dfLw6 = dfLw6.iloc[:,2:]
dfLw6.head()
# Out:
#                            1           2           3           4           5  \
# Datetime
# 2013-01-01 00:00  290.427110  294.637194  288.933490  291.203817  291.522491
# 2013-01-01 01:00  290.176136  293.783624  288.527293  291.297583  291.844342
# 2013-01-01 02:00  290.978753  293.727489  287.398894  289.588148  292.824360
# 2013-01-01 03:00  289.840444  292.461794  286.021164  287.677529  292.117132
# 2013-01-01 04:00  288.908426  291.635618  284.789117  289.336223  291.230065
#
#                            6           7
# Datetime
# 2013-01-01 00:00  294.171333  291.982273
# 2013-01-01 01:00  294.431647  292.489398
# 2013-01-01 02:00  294.338034  291.734777
# 2013-01-01 03:00  294.722219  286.311714
# 2013-01-01 04:00  295.151594  285.419526

# %%
dfLw6.plot()

# %%
dfLw6.iloc[:,1].plot()

# %% [markdown]
# Now run the same simulation changing the model

# %%
#!docker run --rm -it -v $(pwd):/work omslab/oms simulation/Radiation/LongWave.sim

# %% [markdown]
# Read the shortwave radiation results

# %%
nameLw5File = 'output/Radiation/LongwaveDownwelling2010_Model5.csv'

# %%
dfLw5= pd.read_csv(nameLw5File,sep=',',skiprows=6,low_memory=False)
dfLw5.head()
# Out:
#    Format  yyyy-MM-dd HH:mm  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0     NaN  2013-01-01 00:00  206.765090  213.431838  208.202009  208.089396
# 1     NaN  2013-01-01 01:00  206.439100  212.392627  207.635986  208.049612
# 2     NaN  2013-01-01 02:00  207.517598  212.658568  206.721999  206.587322
# 3     NaN  2013-01-01 03:00  205.726055  211.386094  205.362330  204.905502
# 4     NaN  2013-01-01 04:00  204.480457  210.290489  203.813614  206.473775
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8
# 0  206.567478  212.323570  209.749438
# 1  206.837946  212.486749  210.165975
# 2  207.877731  212.584150  209.617678
# 3  206.101568  212.970102  203.656142
# 4  205.019558  213.293478  202.451957

# %%
dfLw5.rename(columns={list(dfLw5)[1]:'Datetime'}, inplace=True)
dfLw5[dfLw5 ==-9999]=np.nan

# %%
for x in range(2, 9):
    dfLw5.rename(columns={list(dfLw5)[x]:x-1}, inplace=True)

# %%
dfLw5.head()
# Out:
#    Format          Datetime           1           2           3           4  \
# 0     NaN  2013-01-01 00:00  206.765090  213.431838  208.202009  208.089396
# 1     NaN  2013-01-01 01:00  206.439100  212.392627  207.635986  208.049612
# 2     NaN  2013-01-01 02:00  207.517598  212.658568  206.721999  206.587322
# 3     NaN  2013-01-01 03:00  205.726055  211.386094  205.362330  204.905502
# 4     NaN  2013-01-01 04:00  204.480457  210.290489  203.813614  206.473775
#
#             5           6           7
# 0  206.567478  212.323570  209.749438
# 1  206.837946  212.486749  210.165975
# 2  207.877731  212.584150  209.617678
# 3  206.101568  212.970102  203.656142
# 4  205.019558  213.293478  202.451957

# %%
dfLw5['Datetime'] = pd.to_datetime(dfLw5['Datetime'], dayfirst=True)
dfLw5['Datetime'] = dfLw5['Datetime'].dt.strftime('%Y-%m-%d %H:%M')
dfLw5.index = dfLw5.Datetime

# %%
dfLw5 = dfLw5.iloc[:,2:]
dfLw5.head()
# Out:
#                            1           2           3           4           5  \
# Datetime
# 2013-01-01 00:00  206.765090  213.431838  208.202009  208.089396  206.567478
# 2013-01-01 01:00  206.439100  212.392627  207.635986  208.049612  206.837946
# 2013-01-01 02:00  207.517598  212.658568  206.721999  206.587322  207.877731
# 2013-01-01 03:00  205.726055  211.386094  205.362330  204.905502  206.101568
# 2013-01-01 04:00  204.480457  210.290489  203.813614  206.473775  205.019558
#
#                            6           7
# Datetime
# 2013-01-01 00:00  212.323570  209.749438
# 2013-01-01 01:00  212.486749  210.165975
# 2013-01-01 02:00  212.584150  209.617678
# 2013-01-01 03:00  212.970102  203.656142
# 2013-01-01 04:00  213.293478  202.451957

# %%
dfLw5.iloc[:,1].plot()
dfLw6.iloc[:,1].plot()

# %%
dfResidual = dfLw6 - dfLw5
dfResidual.plot()

# %%
dfResidual.iloc[:,1].plot()

# %% [markdown]
# # Longwave raster

# %%
import numpy as np
raster_path = 'data/DemMeledrioLowResolution.asc'
with open(raster_path, 'r') as raster:
    raster_header = raster.readlines()[:6]
raster_header = [item.strip().split()[-1] for item in raster_header]
raster_cols = int(raster_header[0])
raster_rows = int(raster_header[1])
raster_xll = float(raster_header[2])
raster_yll = float(raster_header[3])
raster_cs = float(raster_header[4])
raster_nodata = float(raster_header[5])
raster_array = np.loadtxt(raster_path, dtype=np.float, skiprows=6)
raster_array[raster_array == raster_nodata] = np.nan

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10,6))
ax.set_title('DEM')
raster_extent = [
    raster_xll, raster_xll + raster_cols * raster_cs,
    raster_yll, raster_yll + raster_rows * raster_cs]
img_plot = ax.imshow(raster_array, extent=raster_extent, cmap='terrain')
cbar = plt.colorbar(img_plot, orientation='vertical', shrink=0.5, aspect=14)
cbar.set_label('Elevation [m]')
plt.show()

# %%
os.chdir(projFolder)

# %%
raster_path = 'output/Kriging/Mappa_TemperatureMean_20100430_1200.asc'
with open(raster_path, 'r') as raster:
    raster_header = raster.readlines()[:6]
raster_header = [item.strip().split()[-1] for item in raster_header]
raster_cols = int(raster_header[0])
raster_rows = int(raster_header[1])
raster_xll = float(raster_header[2])
raster_yll = float(raster_header[3])
raster_cs = float(raster_header[4])
raster_nodata = float(raster_header[5])
raster_array = np.loadtxt(raster_path, dtype=np.float, skiprows=6)
raster_array[raster_array == raster_nodata] = np.nan

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.set_title('Temperature')
raster_extent = [
    raster_xll, raster_xll + raster_cols * raster_cs,
    raster_yll, raster_yll + raster_rows * raster_cs]
img_plot = ax.imshow(raster_array, extent=raster_extent, cmap='gnuplot')
cbar = plt.colorbar(img_plot, orientation='vertical', shrink=0.5, aspect=14)
cbar.set_label('Temperature')
plt.show()

# %%
raster_path = 'output/Radiation/skyviewLowRes.asc'
with open(raster_path, 'r') as raster:
    raster_header = raster.readlines()[:6]
raster_header = [item.strip().split()[-1] for item in raster_header]
raster_cols = int(raster_header[0])
raster_rows = int(raster_header[1])
raster_xll = float(raster_header[2])
raster_yll = float(raster_header[3])
raster_cs = float(raster_header[4])
raster_nodata = float(raster_header[5])
raster_array = np.loadtxt(raster_path, dtype=np.float, skiprows=6)
raster_array[raster_array == raster_nodata] = np.nan

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.set_title('Skyview factor')
raster_extent = [
    raster_xll, raster_xll + raster_cols * raster_cs,
    raster_yll, raster_yll + raster_rows * raster_cs]
img_plot = ax.imshow(raster_array, extent=raster_extent, cmap='gnuplot')
cbar = plt.colorbar(img_plot, orientation='vertical', shrink=0.5, aspect=14)
cbar.set_label('')
plt.show()

# %% [markdown]
# In this simulation the parameters a and b are equal to:
# - A_Cloud = 0.4
# - B_Cloud = 0.8

# %%
# !docker run --rm -it -v $(pwd):/work omslab/oms simulation/Radiation/LongWave_raster.sim
# Out:
# build/ folder exists: project already built.
# Reading coverage: Mappa_TemperatureMean_20100430_1200.asc
# Reading coverage: skyviewLowRes.asc
# Finished.
# Finished.
# Writing coverage: LwrbDownWellingRaster0010.asc
# Writing coverage: LwrbUpWellingRaster0010.asc
# Jan 15, 2019 11:00:18 AM java.util.prefs.FileSystemPreferences$1 run
# INFO: Created user preferences directory.
# Finished.
# Finished.
#
# *********************************
# ***     END OF SIMULATION     ***
# *********************************

# %%
os.getcwd()
# Out:
# '/home/drugo/Desktop/MeledrioCaseStudy-winterSchool'

# %%
raster_path = 'output/Radiation/LwrbDownWellingRaster0408.asc'
with open(raster_path, 'r') as raster:
    raster_header = raster.readlines()[:6]
raster_header = [item.strip().split()[-1] for item in raster_header]
raster_cols = int(raster_header[0])
raster_rows = int(raster_header[1])
raster_xll = float(raster_header[2])
raster_yll = float(raster_header[3])
raster_cs = float(raster_header[4])
raster_nodata = float(raster_header[5])
raster_array = np.loadtxt(raster_path, dtype=np.float, skiprows=6)
raster_array[raster_array == raster_nodata] = np.nan

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10,10))
ax.set_title('Downwelling longWave radiation')
raster_extent = [
    raster_xll, raster_xll + raster_cols * raster_cs,
    raster_yll, raster_yll + raster_rows * raster_cs]
img_plot = ax.imshow(raster_array, extent=raster_extent, cmap='gnuplot')
cbar = plt.colorbar(img_plot, orientation='vertical', shrink=0.5, aspect=14)
cbar.set_label('Radiation [W/m2]')
plt.show()

# %%
raster_path = 'output/Radiation/LwrbUpWellingRaster0408.asc'
with open(raster_path, 'r') as raster:
    raster_header = raster.readlines()[:6]
raster_header = [item.strip().split()[-1] for item in raster_header]
raster_cols = int(raster_header[0])
raster_rows = int(raster_header[1])
raster_xll = float(raster_header[2])
raster_yll = float(raster_header[3])
raster_cs = float(raster_header[4])
raster_nodata = float(raster_header[5])
raster_array = np.loadtxt(raster_path, dtype=np.float, skiprows=6)
raster_array[raster_array == raster_nodata] = np.nan

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10,10))
ax.set_title('Upwelling longWave radiation')
raster_extent = [
    raster_xll, raster_xll + raster_cols * raster_cs,
    raster_yll, raster_yll + raster_rows * raster_cs]
img_plot = ax.imshow(raster_array, extent=raster_extent, cmap='gnuplot')
cbar = plt.colorbar(img_plot, orientation='vertical', shrink=0.5, aspect=14)
cbar.set_label('Radiation [W/m2]')
plt.show()

# %% [markdown]
# In this simulation the parameters a and b are equal to:
# - A_Cloud = 0
# - B_Cloud = 1

# %%
# !docker run --rm -it -v $(pwd):/work omslab/oms simulation/Radiation/LongWave_raster.sim
# Out:
# build/ folder exists: project already built.
# Reading coverage: Mappa_TemperatureMean_20100430_1200.asc
# Reading coverage: skyviewLowRes.asc
# Finished.
# Finished.
# Writing coverage: LwrbUpWellingRaster0010.asc
# Writing coverage: LwrbDownWellingRaster0010.asc
# Jan 14, 2019 9:12:39 PM java.util.prefs.FileSystemPreferences$1 run
# INFO: Created user preferences directory.
# Finished.
# Finished.
#
# *********************************
# ***     END OF SIMULATION     ***
# *********************************

# %%
os.getcwd()
# Out:
# '/home/drugo/Desktop/MeledrioCaseStudy-winterSchool'

# %%
raster_path = 'output/Radiation/LwrbDownWellingRaster0010.asc'
with open(raster_path, 'r') as raster:
    raster_header = raster.readlines()[:6]
raster_header = [item.strip().split()[-1] for item in raster_header]
raster_cols = int(raster_header[0])
raster_rows = int(raster_header[1])
raster_xll = float(raster_header[2])
raster_yll = float(raster_header[3])
raster_cs = float(raster_header[4])
raster_nodata = float(raster_header[5])
raster_array = np.loadtxt(raster_path, dtype=np.float, skiprows=6)
raster_array[raster_array == raster_nodata] = np.nan

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10,10))
ax.set_title('Downwelling longWave radiation')
raster_extent = [
    raster_xll, raster_xll + raster_cols * raster_cs,
    raster_yll, raster_yll + raster_rows * raster_cs]
img_plot = ax.imshow(raster_array, extent=raster_extent, cmap='gnuplot')
cbar = plt.colorbar(img_plot, orientation='vertical', shrink=0.5, aspect=14)
cbar.set_label('Radiation [W/m2]')
plt.show()

# %%
raster_path = 'output/Radiation/LwrbUpWellingRaster0010.asc'
with open(raster_path, 'r') as raster:
    raster_header = raster.readlines()[:6]
raster_header = [item.strip().split()[-1] for item in raster_header]
raster_cols = int(raster_header[0])
raster_rows = int(raster_header[1])
raster_xll = float(raster_header[2])
raster_yll = float(raster_header[3])
raster_cs = float(raster_header[4])
raster_nodata = float(raster_header[5])
raster_array = np.loadtxt(raster_path, dtype=np.float, skiprows=6)
raster_array[raster_array == raster_nodata] = np.nan

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10,10))
ax.set_title('Upwelling longWave radiation')
raster_extent = [
    raster_xll, raster_xll + raster_cols * raster_cs,
    raster_yll, raster_yll + raster_rows * raster_cs]
img_plot = ax.imshow(raster_array, extent=raster_extent, cmap='gnuplot')
cbar = plt.colorbar(img_plot, orientation='vertical', shrink=0.5, aspect=14)
cbar.set_label('Radiation [W/m2]')
plt.show()
